# %%
import pandas as pd

# %%
c = pd.read_csv("cases_malaysia.csv")

# %%
c.tail()
# Out:
#            date  cases_new  cases_import  cases_recovered  cases_active  \
# 979  2022-09-30       2007            12             1407         25769
# 980  2022-10-01       1626             5             2386         25009
# 981  2022-10-02       1360             1             2271         24097
# 982  2022-10-03       1244             4             2005         23331
# 983  2022-10-04       1483             4             1852         22957
#
#      cases_cluster  cases_unvax  cases_pvax  cases_fvax  cases_boost  ...  \
# 979              7          171           9         371         1456  ...
# 980              0          172           9         327         1118  ...
# 981              0          125           2         240          993  ...
# 982             13          122           5         235          882  ...
# 983              0          152           8         288         1035  ...
#
#      cases_70_79  cases_80  cluster_import  cluster_religious  \
# ...

# %%
c['total_cases'] = c.cumsum()['cases_new']
# c.tail()

# %%
c.to_csv("cleaned_cases_malaysia.csv")
